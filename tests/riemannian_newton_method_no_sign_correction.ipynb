# %%
import os
from pathlib import Path


os.chdir(Path.cwd().parent)

# %%
import matplotlib.pyplot as plt
import numpy as np
import sys

from src.optimizers.step_controllers.step_controllers import (
    StepControllerBase, ConstantController, BacktrackingLineSearchController
)
from src.optimizers.riemannian_newton_method import RiemannianNewtonIterations
from src.optimizers.utils.report import basic_report
from src.rayleigh_quotient import rayleigh_quotient
from src.utils.linalg import (
    generate_normalized_vector, generate_supersymmetric_tensor, tenvec
)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
def test_riemannian_newton_method_base(
    A: np.ndarray,
    x: np.ndarray,
    step_controllers: list[StepControllerBase] = [ConstantController(), BacktrackingLineSearchController()],
    *,
    plot: bool = False,
    show_label: bool = False,
    verbose: bool = False) -> None:
    """
    Ensures Riemannian Newthon method for f(x) = R_A(X) converges to eigenpair.

    :param A: supersymmetric tensor of shape (n x n x ... x n) of order k
    :param x: normalized vector of shape (n,)
    :paran step_controllers: step controllers to use.
        Default is to use all implemented with default parameters
    :param plot: whether to plot f_history and f_grad_norm_history
    :param show_label: whether to show label(name) of step controller when plotting
    :param verbose: whether to print more info
    """
    if verbose:
        print(f"testing Riemannian Newton method with parameters:\n"
              f"tensor A of shape {A.shape}\nA = {A}\n"
              f"vector x = {x}")
    k = A.ndim
    method = RiemannianNewtonIterations.from_tensor(A, invalid="ignore")

    if plot:
        fig, axs = plt.subplots(3, 2, figsize=(12, 12))
        fig.suptitle(f"Riemannian-Newthon method iteration statistics for tensor of shape {A.shape}", fontsize=18)

        axs[0, 0].set(title="Rayleigh quotient values log scaled")
        axs[0, 1].set(title="Rayleigh quotient residual values log scaled")
        axs[1, 0].set(title="Rayleigh quotient gradient norm values log scaled")
        axs[1, 1].set(title="Rayleigh quotient gradient residual norm values log scaled")
        axs[2, 0].set(title="Linear solver deviation log scaled")
        axs[2, 1].set(title="Step sign on each iteration")

    success_all = True
    for step_controller in step_controllers:
        name = step_controller.name()
        X_eign = method.minimize(x, step_controller=step_controller)
        rq_eign = rayleigh_quotient(A, X_eign)

        X_expected = rq_eign * X_eign
        X_computed = tenvec(A, X_eign, times=k-1)

        success = np.allclose(X_expected, X_computed, atol=1e-4)
        if success:
            if plot:
                f_hist, f_residual_hist, f_grad_norm_hist, f_grad_residual_norm_hist = basic_report(method._f, method._f_grad, method._x_history)
                yscales = np.array([
                    ['linear', 'log'], ['log', 'log'], ['log', 'linear']
                ])
                for i, stat in enumerate([
                    f_hist, f_residual_hist, f_grad_norm_hist,
                    f_grad_residual_norm_hist, method.lin_solver_error_history, np.sign(method._step_history)
                    ]):
                    idx = np.unravel_index(i, (3, 2))
                    axs[idx].plot(range(len(stat)), stat, label=name)
                    axs[idx].set_yscale(yscales[idx])
                    axs[idx].grid(True)
                    if show_label:
                        axs[idx].legend()

                fig.tight_layout()

        else:
            print(f"Riemannian-Newton method with {name} step controller failed", file=sys.stderr)
            success_all = False
    assert success_all

# %%
def test_riemannian_newton_method_simple() -> None:
    n = 2
    k = 2
    a = generate_supersymmetric_tensor(n, k)
    x = generate_normalized_vector(n)
    test_riemannian_newton_method_base(a, x, plot=True, show_label=True)

def test_riemannian_newton_method_simple_demo() -> None:
    n = 2
    k = 2
    a = generate_supersymmetric_tensor(n, k)
    x = generate_normalized_vector(n)
    test_riemannian_newton_method_base(a, x, [ConstantController()], plot=True, show_label=False)

def test_riemannian_newton_method_medium() -> None:
    n = 3
    k = 3
    a = generate_supersymmetric_tensor(n, k)
    x = generate_normalized_vector(n)
    test_riemannian_newton_method_base(a, x, plot=True, show_label=True)

def test_riemannian_newton_method_hard() -> None:
    n = 6
    k = 6
    a = generate_supersymmetric_tensor(n, k)
    x = generate_normalized_vector(n)
    test_riemannian_newton_method_base(a, x, plot=True, show_label=True)

# %%
test_riemannian_newton_method_simple()

# %%
test_riemannian_newton_method_simple_demo()

# %%
test_riemannian_newton_method_medium()
# Out:
# /home/chep0k/hse/3-course/jdm/src/optimizers/riemannian_newton_method.py:47: UserWarning: max iterations reached
#   warnings.warn("max iterations reached")
# Riemannian-Newton method with backtracking line search step controller failed
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 test_riemannian_newton_method_medium()
#
# Cell In[5], line 20, in test_riemannian_newton_method_medium()
#      18 a = generate_supersymmetric_tensor(n, k)
#      19 x = generate_normalized_vector(n)
# ---> 20 test_riemannian_newton_method_base(a, x, plot=True, show_label=True)
#
# Cell In[4], line 70, in test_riemannian_newton_method_base(A, x, step_controllers, plot, show_label, verbose)
#      68         print(f"Riemannian-Newton method with {name} step controller failed", file=sys.stderr)
#      69         success_all = False
# ---> 70 assert success_all
#
# AssertionError:

# %%
test_riemannian_newton_method_hard()
# Out:
# ---------------------------------------------------------------------------
# ConvergenceError                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 test_riemannian_newton_method_hard()
#
# Cell In[5], line 27, in test_riemannian_newton_method_hard()
#      25 a = generate_supersymmetric_tensor(n, k)
#      26 x = generate_normalized_vector(n)
# ---> 27 test_riemannian_newton_method_base(a, x, plot=True, show_label=True)
#
# Cell In[4], line 41, in test_riemannian_newton_method_base(A, x, step_controllers, plot, show_label, verbose)
#      39 for step_controller in step_controllers:
#      40     name = step_controller.name()
# ---> 41     X_eign = method.minimize(x, step_controller=step_controller)
#      42     rq_eign = rayleigh_quotient(A, X_eign)
#      44     X_expected = rq_eign * X_eign
#
# File ~/hse/3-course/jdm/src/utils/testing.py:26, in verify_not_modified.<locals>.wrapper_wrapper.<locals>.wrapper(*args, **kwargs)
#      23     args_copy = copy.deepcopy(args)
#      24     kwargs_copy = copy.deepcopy(kwargs)
# ---> 26 result = func(*args, **kwargs)
#      28 if act:
#      29     assert str(args) == str(args_copy), f"{args=}\n{args_copy=}"
#
# File ~/hse/3-course/jdm/src/optimizers/_base.py:63, in GradientDescentBase.minimize(self, x_0, step_controller)
#      60 @verify_not_modified(VERIFY_NOT_MODIFIED)
#      61 def minimize(self, x_0: np.ndarray, step_controller: StepControllerBase) -> np.ndarray:
#      62     self._reset()
# ---> 63     x = self._minimize_impl(x_0, step_controller)
#      64     return x
#
# File ~/hse/3-course/jdm/src/utils/testing.py:26, in verify_not_modified.<locals>.wrapper_wrapper.<locals>.wrapper(*args, **kwargs)
#      23     args_copy = copy.deepcopy(args)
#      24     kwargs_copy = copy.deepcopy(kwargs)
# ---> 26 result = func(*args, **kwargs)
#      28 if act:
#      29     assert str(args) == str(args_copy), f"{args=}\n{args_copy=}"
#
# File ~/hse/3-course/jdm/src/optimizers/riemannian_newton_method.py:57, in RiemannianNewtonIterations._minimize_impl(self, x_0, step_controller)
#      54     break
#      56 hess = self._f_hess(x)
# ---> 57 xi, _ = krypy.minres(hess, -grad)
#      58 xi_tangent = xi - (x.T @ xi) * x  # xi_tangent = projection(x) @ xi
#      60 err = np.linalg.norm(hess @ xi_tangent + grad)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/krypy/_convenience.py:122, in minres(A, b, M, Minv, Ml, Mr, inner_product, exact_solution, ortho, x0, U, tol, maxiter, use_explicit_residual, store_arnoldi)
#     110 linear_system = LinearSystem(
#     111     A=A,
#     112     b=b,
#    (...)
#     119     exact_solution=exact_solution,
#     120 )
#     121 if U is None:
# --> 122     out = Minres(
#     123         linear_system,
#     124         ortho=ortho,
#     125         x0=x0,
#     126         tol=tol,
#     127         maxiter=maxiter,
#     128         explicit_residual=use_explicit_residual,
#     129         store_arnoldi=store_arnoldi,
#     130     )
#     131 else:
#     132     out = DeflatedMinres(
#     133         linear_system,
#     134         ortho=ortho,
#    (...)
#     140         store_arnoldi=store_arnoldi,
#     141     )
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/krypy/linsys.py:724, in Minres.__init__(self, linear_system, ortho, **kwargs)
#     721     warnings.warn('Minres applied to a non-self-adjoint '
#     722                   'linear system. Consider using Gmres.')
#     723 self.ortho = ortho
# --> 724 super(Minres, self).__init__(linear_system, **kwargs)
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/krypy/linsys.py:372, in _KrylovSolver.__init__(self, linear_system, x0, tol, maxiter, explicit_residual, store_arnoldi, dtype)
#     366     '''Error norms.'''
#     368     self.errnorms.append(utils.norm(
#     369         self.linear_system.exact_solution - self._get_xk(None),
#     370         ip_B=self.linear_system.ip_B))
# --> 372 self._solve()
#     373 self._finalize()
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/krypy/linsys.py:801, in Minres._solve(self)
#     798     yk = yk + y[0] * z
#     799     y = [y[1], 0]
# --> 801     self._finalize_iteration(yk, numpy.abs(y[0]))
#     803 # compute solution if not yet done
#     804 if self.xk is None:
#
# File ~/.pyenv/versions/3.10.6/lib/python3.10/site-packages/krypy/linsys.py:435, in _KrylovSolver._finalize_iteration(self, yk, resnorm)
#     433 if self.iter+1 == self.maxiter:
#     434     self._finalize()
# --> 435     raise utils.ConvergenceError(
#     436         ('No convergence in last iteration '
#     437          f'(maxiter: {self.maxiter}, '
#     438          f'residual: {self.resnorms[-1]}).'),
#     439          self)
#     440 # updated residual was below but explicit is not: warn
#     441 elif not self.explicit_residual \
#     442         and resnorm/self.linear_system.MMlb_norm <= self.tol:
#
# ConvergenceError: No convergence in last iteration (maxiter: 6, residual: 0.9660399740501316).
